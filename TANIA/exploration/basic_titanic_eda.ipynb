# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# I ripped this EDA from kaggle kernels, with some edits by me. Please skim through this, but don't spend too much time trying to understand everything. Having a general level of data understanding is enough.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('../input/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### How many Survived??

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# It is evident that not many passengers survived the accident.
#
# Out of 891 passengers in training set, only around 350 survived i.e Only **38.4%** of the total training set survived the crash. We need to dig down more to get better insights from the data and see which categories of the passengers did survive and who didn't.
#
# We will try to check the survival rate by using the different features of the dataset. Some of the features being Sex, Port Of Embarcation, Age,etc.
#
# First let us understand the different types of features.

# %% [markdown]
# ## Types Of Features
#
# ### Categorical Features:
# A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables. They are also known as **Nominal Variables**.
#
# **Categorical Features in the dataset: Sex,Embarked.**
#
# ### Ordinal Features:
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values. For eg: If we have a feature like **Height** with values **Tall, Medium, Short**, then Height is a ordinal variable. Here we can have a relative sort in the variable.
#
# **Ordinal Features in the dataset: PClass**
#
# ### Discrete Numeric Features:
# Discrete Numeric features are real-valued features that can only take on discrete values. An example would be "count of people".
#
# **Discrete Numerical Features in the dataset: Parch, Sibsp**
#
# ### Continous Numeric Features:
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.
#
# **Continous Features in the dataset: Age**

# %% [markdown]
#  ## Analysing The Features

# %% [markdown]
# ## Sex--> Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# This looks interesting. The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved. The survival rates for a **women on the ship is around 75% while that for men in around 18-19%.**
#
# This looks to be a **very important** feature for modeling. But is it the best??   Lets check other features.

# %% [markdown]
# ## Pclass --> Ordinal Feature

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a468c75c_e527_11e8_a859_720002ee9960row0_col0 {
#             background-color:  #ffff66;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row0_col1 {
#             background-color:  #cee666;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row1_col1 {
#             background-color:  #ffff66;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row1_col2 {
#             background-color:  #ffff66;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row2_col0 {
#             background-color:  #60b066;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row2_col1 {
#             background-color:  #dfef66;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row2_col2 {
#             background-color:  #90c866;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row3_col0 {
#             background-color:  #008066;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row3_col1 {
#             background-color:  #008066;
#         }    #T_a468c75c_e527_11e8_a859_720002ee9960row3_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_a468c75c_e527_11e8_a859_720002ee9960" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a468c75c_e527_11e8_a859_720002ee9960level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row0_col0" class="data row0 col0" >80</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row0_col1" class="data row0 col1" >136</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_a468c75c_e527_11e8_a859_720002ee9960level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row1_col0" class="data row1 col0" >97</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row1_col1" class="data row1 col1" >87</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_a468c75c_e527_11e8_a859_720002ee9960level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row2_col0" class="data row2 col0" >372</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row2_col1" class="data row2 col1" >119</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_a468c75c_e527_11e8_a859_720002ee9960level0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row3_col0" class="data row3 col0" >549</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row3_col1" class="data row3 col1" >342</td>
#         <td id="T_a468c75c_e527_11e8_a859_720002ee9960row3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# People say **Money Can't Buy Everything**. But we can clearly see that Passenegers Of Pclass 1 were given a very high priority while rescue. Even though the the number of Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low, somewhere around **25%**.
#
# For Pclass 1 %survived is around **63%** while for Pclass2 is around **48%**. So money and status matters. Such a materialistic world.
#
# Lets Dive in little bit more and check for other interesting observations. Lets check survival rate with **Sex and Pclass** Together.

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col0 {
#             background-color:  #ffff66;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col1 {
#             background-color:  #ffff66;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col2 {
#             background-color:  #f1f866;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col3 {
#             background-color:  #ffff66;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col0 {
#             background-color:  #96cb66;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col1 {
#             background-color:  #a3d166;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col2 {
#             background-color:  #f1f866;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col3 {
#             background-color:  #cfe766;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col0 {
#             background-color:  #a7d366;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col1 {
#             background-color:  #85c266;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col2 {
#             background-color:  #6eb666;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col3 {
#             background-color:  #85c266;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col0 {
#             background-color:  #cde666;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col1 {
#             background-color:  #f0f866;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col2 {
#             background-color:  #ffff66;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col3 {
#             background-color:  #f7fb66;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col0 {
#             background-color:  #008066;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col1 {
#             background-color:  #008066;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col2 {
#             background-color:  #008066;
#         }    #T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_a4bee93e_e527_11e8_8d9c_720002ee9960" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col0" class="data row0 col0" >3</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col1" class="data row0 col1" >6</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col2" class="data row0 col2" >72</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col0" class="data row1 col0" >91</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col1" class="data row1 col1" >70</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col2" class="data row1 col2" >72</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row1_col3" class="data row1 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col0" class="data row2 col0" >77</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col1" class="data row2 col1" >91</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col2" class="data row2 col2" >300</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row2_col3" class="data row2 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col0" class="data row3 col0" >45</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col1" class="data row3 col1" >17</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col2" class="data row3 col2" >47</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_a4bee93e_e527_11e8_8d9c_720002ee9960level1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col0" class="data row4 col0" >216</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col1" class="data row4 col1" >184</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col2" class="data row4 col2" >491</td>
#         <td id="T_a4bee93e_e527_11e8_8d9c_720002ee9960row4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# We use **FactorPlot** in this case, because they make the seperation of categorical values easy.
#
# Looking at the **CrossTab** and the **FactorPlot**, we can easily infer that survival for **Women from Pclass1** is about **95-96%**, as only 3 out of 94 Women from Pclass1 died.
#
# It is evident that irrespective of Pclass, Women were given first priority while rescue. Even Men from Pclass1 have a very low survival rate.
#
# Looks like Pclass is also an important feature. Lets analyse other features.

# %% [markdown]
# ## Age--> Continous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# #### Observations:
#
# 1)The number of children increases with Pclass and the survival rate for passenegers below Age 10(i.e children) looks to be good irrespective of the Pclass.
#
# 2)Survival chances for Passenegers aged 20-50 from Pclass1 is high and is even better for Women.
#
# 3)For males, the survival chances decreases with an increase in age.

# %% [markdown]
# As we had seen earlier, the Age feature has **177** null values. To replace these NaN values, we can assign them the mean age of the dataset.
#
# But the problem is, there were many people with many different ages. We just cant assign a 4 year kid with the mean age that is 29 years. Is there any way to find out what age-band does the passenger lie??
#
# **Bingo!!!!**, we can check the **Name**  feature. Looking upon the feature, we can see that the names have a salutation like Mr or Mrs. Thus we can assign the mean values of Mr and Mrs to the respective groups.
#
# **''What's In A Name??''**---> **Feature**

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %% [markdown]
# Okay so here we are using the Regex: **[A-Za-z]+)\.**. So what it does is, it looks for strings which lie between **A-Z or a-z** and followed by a **.(dot)**. So we successfully extract the Initials from the Name.

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col0 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col1 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col2 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col3 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col4 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col5 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col6 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col7 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col8 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col9 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col10 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col11 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col12 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col13 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col14 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col15 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col16 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col0 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col1 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col2 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col3 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col4 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col5 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col6 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col7 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col8 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col9 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col10 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col11 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col12 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col13 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col14 {
#             background-color:  #ffff66;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col15 {
#             background-color:  #008066;
#         }    #T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_a5678d6e_e527_11e8_9f73_720002ee9960" >
# <thead>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Countess</th>
#         <th class="col_heading level0 col3" >Don</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a5678d6e_e527_11e8_9f73_720002ee9960level0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col0" class="data row0 col0" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col1" class="data row0 col1" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col2" class="data row0 col2" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col3" class="data row0 col3" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col4" class="data row0 col4" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col5" class="data row0 col5" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col6" class="data row0 col6" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col7" class="data row0 col7" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col8" class="data row0 col8" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col9" class="data row0 col9" >182</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col10" class="data row0 col10" >2</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col11" class="data row0 col11" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col12" class="data row0 col12" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col13" class="data row0 col13" >125</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col14" class="data row0 col14" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col15" class="data row0 col15" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_a5678d6e_e527_11e8_9f73_720002ee9960level0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col0" class="data row1 col0" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col1" class="data row1 col1" >2</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col2" class="data row1 col2" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col3" class="data row1 col3" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col4" class="data row1 col4" >6</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col5" class="data row1 col5" >1</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_col6" class="data row1 col6" >0</td>
#         <td id="T_a5678d6e_e527_11e8_9f73_720002ee9960row1_c

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any() #So no null values left finally
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# ### Observations:
# 1)The Toddlers(age<5) were saved in large numbers(The Women and Child First Policy).
#
# 2)The oldest Passenger was saved(80 years).
#
# 3)Maximum number of deaths were in the age group of 30-40.

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %% [markdown]
# The Women and Child first policy thus holds true irrespective of the class.

# %% [markdown]
# ## Embarked--> Categorical Value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a6719068_e527_11e8_8171_720002ee9960row0_col0 {
#             background-color:  #fcfe66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row0_col1 {
#             background-color:  #d2e866;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row0_col2 {
#             background-color:  #f2f866;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row0_col3 {
#             background-color:  #d8ec66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row0_col4 {
#             background-color:  #e8f466;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row1_col0 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row1_col1 {
#             background-color:  #f9fc66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row1_col2 {
#             background-color:  #fcfe66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row1_col3 {
#             background-color:  #fbfd66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row1_col4 {
#             background-color:  #fbfd66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row2_col0 {
#             background-color:  #e6f266;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row2_col1 {
#             background-color:  #f0f866;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row2_col2 {
#             background-color:  #eef666;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row2_col3 {
#             background-color:  #e8f466;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row2_col4 {
#             background-color:  #edf666;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row3_col0 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row3_col1 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row3_col2 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row3_col3 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row3_col4 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row4_col0 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row4_col1 {
#             background-color:  #fefe66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row4_col2 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row4_col3 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row4_col4 {
#             background-color:  #ffff66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row5_col0 {
#             background-color:  #e3f166;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row5_col1 {
#             background-color:  #e6f266;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row5_col2 {
#             background-color:  #ecf666;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row5_col3 {
#             background-color:  #f8fc66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row5_col4 {
#             background-color:  #ebf566;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row6_col0 {
#             background-color:  #f9fc66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row6_col1 {
#             background-color:  #cde666;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row6_col2 {
#             background-color:  #e4f266;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row6_col3 {
#             background-color:  #bede66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row6_col4 {
#             background-color:  #dbed66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row7_col0 {
#             background-color:  #edf666;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row7_col1 {
#             background-color:  #bdde66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row7_col2 {
#             background-color:  #d3e966;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row7_col3 {
#             background-color:  #dcee66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row7_col4 {
#             background-color:  #d1e866;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row8_col0 {
#             background-color:  #52a866;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row8_col1 {
#             background-color:  #dcee66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row8_col2 {
#             background-color:  #81c066;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row8_col3 {
#             background-color:  #b0d866;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row8_col4 {
#             background-color:  #9acc66;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row9_col0 {
#             background-color:  #008066;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row9_col1 {
#             background-color:  #008066;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row9_col2 {
#             background-color:  #008066;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row9_col3 {
#             background-color:  #008066;
#         }    #T_a6719068_e527_11e8_8171_720002ee9960row9_col4 {
#             background-color:  #008066;
#         }</style>
# <table id="T_a6719068_e527_11e8_8171_720002ee9960" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Sex</th>
#         <th class="col_heading level0 col0" colspan=2>female</th>
#         <th class="col_heading level0 col2" colspan=2>male</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Survived</th>
#         <th class="col_heading level1 col0" >0</th>
#         <th class="col_heading level1 col1" >1</th>
#         <th class="col_heading level1 col2" >0</th>
#         <th class="col_heading level1 col3" >1</th>
#         <th class="col_heading level1 col4" ></th>
#     </tr>    <tr>
#         <th class="index_name level0" >Embarked</th>
#         <th class="index_name level1" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a6719068_e527_11e8_8171_720002ee9960level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#         <th id="T_a6719068_e527_11e8_8171_720002ee9960level1_row0" class="row_heading level1 row0" >1</th>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row0_col0" class="data row0 col0" >1</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row0_col1" class="data row0 col1" >42</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row0_col2" class="data row0 col2" >25</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row0_col3" class="data row0 col3" >17</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row0_col4" class="data row0 col4" >85</td>
#     </tr>    <tr>
#         <th id="T_a6719068_e527_11e8_8171_720002ee9960level1_row1" class="row_heading level1 row1" >2</th>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row1_col0" class="data row1 col0" >0</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row1_col1" class="data row1 col1" >7</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row1_col2" class="data row1 col2" >8</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row1_col3" class="data row1 col3" >2</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row1_col4" class="data row1 col4" >17</td>
#     </tr>    <tr>
#         <th id="T_a6719068_e527_11e8_8171_720002ee9960level1_row2" class="row_heading level1 row2" >3</th>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row2_col0" class="data row2 col0" >8</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row2_col1" class="data row2 col1" >15</td>
#         <td id="T_a6719068_e527_11e8_8171_720002ee9960row2_col2" class=

# %% [markdown]
# ### Chances for Survival by Port Of Embarkation

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %% [markdown]
# The chances for survival for Port C is highest around 0.55 while it is lowest for S.

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# ### Observations:
# 1)Maximum passenegers boarded from S. Majority of them being from Pclass3.
#
# 2)The Passengers from C look to be lucky as a good proportion of them survived. The reason for this maybe the rescue of all the Pclass1 and Pclass2 Passengers.
#
# 3)The Embark S looks to the port from where majority of the rich people boarded. Still the chances for survival is low here, that is because many passengers from Pclass3 around **81%** didn't survive.
#
# 4)Port Q had almost 95% of the passengers were from Pclass3.

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# ### Observations:
#
# 1)The survival chances are almost 1 for women for Pclass1 and Pclass2 irrespective of the Pclass.
#
# 2)Port S looks to be very unlucky for Pclass3 Passenegers as the survival rate for both men and women is very low.**(Money Matters)**
#
# 3)Port Q looks looks to be unlukiest for Men, as almost all were from Pclass 3.

# %% [markdown]
# ### Filling Embarked NaN
#
# As we saw that maximum passengers boarded from Port S, we replace NaN with S.

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()# Finally No NaN values
# Out:
# False

# %% [markdown]
# ## SibSip-->Discrete Feature
# This feature represents whether a person is alone or with his family members.
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row0_col0 {
#             background-color:  #008066;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row0_col1 {
#             background-color:  #008066;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row1_col0 {
#             background-color:  #c4e266;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row1_col1 {
#             background-color:  #77bb66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row2_col0 {
#             background-color:  #f9fc66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row2_col1 {
#             background-color:  #f0f866;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row3_col0 {
#             background-color:  #fbfd66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row3_col1 {
#             background-color:  #fbfd66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row4_col0 {
#             background-color:  #f9fc66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row4_col1 {
#             background-color:  #fcfe66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row5_col0 {
#             background-color:  #ffff66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row5_col1 {
#             background-color:  #ffff66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row6_col0 {
#             background-color:  #fefe66;
#         }    #T_a79ec6d8_e527_11e8_bd9e_720002ee9960row6_col1 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SibSp</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row0_col0" class="data row0 col0" >398</td>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row0_col1" class="data row0 col1" >210</td>
#     </tr>    <tr>
#         <th id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row1_col0" class="data row1 col0" >97</td>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row1_col1" class="data row1 col1" >112</td>
#     </tr>    <tr>
#         <th id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row2_col0" class="data row2 col0" >15</td>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row2_col1" class="data row2 col1" >13</td>
#     </tr>    <tr>
#         <th id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row3_col0" class="data row3 col0" >12</td>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row3_col1" class="data row3 col1" >4</td>
#     </tr>    <tr>
#         <th id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row4_col0" class="data row4 col0" >15</td>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row4_col1" class="data row4 col1" >3</td>
#     </tr>    <tr>
#         <th id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row5_col0" class="data row5 col0" >5</td>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row5_col1" class="data row5 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960level0_row6" class="row_heading level0 row6" >8</th>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row6_col0" class="data row6 col0" >7</td>
#         <td id="T_a79ec6d8_e527_11e8_bd9e_720002ee9960row6_col1" class="data row6 col1" >0</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a8283c92_e527_11e8_92de_720002ee9960row0_col0 {
#             background-color:  #008066;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row0_col1 {
#             background-color:  #008066;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row0_col2 {
#             background-color:  #008066;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row1_col0 {
#             background-color:  #7bbd66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row1_col1 {
#             background-color:  #8ac466;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row1_col2 {
#             background-color:  #c6e266;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row2_col0 {
#             background-color:  #f6fa66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row2_col1 {
#             background-color:  #eef666;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row2_col2 {
#             background-color:  #f8fc66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row3_col0 {
#             background-color:  #fafc66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row3_col1 {
#             background-color:  #fdfe66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row3_col2 {
#             background-color:  #fafc66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row4_col0 {
#             background-color:  #ffff66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row4_col1 {
#             background-color:  #ffff66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row4_col2 {
#             background-color:  #f6fa66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row5_col0 {
#             background-color:  #ffff66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row5_col1 {
#             background-color:  #ffff66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row5_col2 {
#             background-color:  #ffff66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row6_col0 {
#             background-color:  #ffff66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row6_col1 {
#             background-color:  #ffff66;
#         }    #T_a8283c92_e527_11e8_92de_720002ee9960row6_col2 {
#             background-color:  #fefe66;
#         }</style>
# <table id="T_a8283c92_e527_11e8_92de_720002ee9960" >
# <thead>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SibSp</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a8283c92_e527_11e8_92de_720002ee9960level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row0_col0" class="data row0 col0" >137</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row0_col1" class="data row0 col1" >120</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row0_col2" class="data row0 col2" >351</td>
#     </tr>    <tr>
#         <th id="T_a8283c92_e527_11e8_92de_720002ee9960level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row1_col0" class="data row1 col0" >71</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row1_col1" class="data row1 col1" >55</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row1_col2" class="data row1 col2" >83</td>
#     </tr>    <tr>
#         <th id="T_a8283c92_e527_11e8_92de_720002ee9960level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row2_col0" class="data row2 col0" >5</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row2_col1" class="data row2 col1" >8</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row2_col2" class="data row2 col2" >15</td>
#     </tr>    <tr>
#         <th id="T_a8283c92_e527_11e8_92de_720002ee9960level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row3_col0" class="data row3 col0" >3</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row3_col1" class="data row3 col1" >1</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row3_col2" class="data row3 col2" >12</td>
#     </tr>    <tr>
#         <th id="T_a8283c92_e527_11e8_92de_720002ee9960level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row4_col0" class="data row4 col0" >0</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row4_col1" class="data row4 col1" >0</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row4_col2" class="data row4 col2" >18</td>
#     </tr>    <tr>
#         <th id="T_a8283c92_e527_11e8_92de_720002ee9960level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row5_col0" class="data row5 col0" >0</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row5_col1" class="data row5 col1" >0</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row5_col2" class="data row5 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_a8283c92_e527_11e8_92de_720002ee9960level0_row6" class="row_heading level0 row6" >8</th>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row6_col0" class="data row6 col0" >0</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row6_col1" class="data row6 col1" >0</td>
#         <td id="T_a8283c92_e527_11e8_92de_720002ee9960row6_col2" class="data row6 col2" >7</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### Observations:
#
#
# The barplot and factorplot shows that if a passenger is alone onboard with no siblings, he have 34.5% survival rate. The graph roughly decreases if the number of siblings increase. This makes sense. That is, if I have a family on board, I will try to save them instead of saving myself first. Surprisingly the survival for families with 5-8 members is **0%**. The reason may be Pclass??
#
# The reason is **Pclass**. The crosstab shows that Person with SibSp>3 were all in Pclass3. It is imminent that all the large families in Pclass3(>3) died.

# %% [markdown]
# ## Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a82e1bda_e527_11e8_a6fe_720002ee9960row0_col0 {
#             background-color:  #008066;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row0_col1 {
#             background-color:  #008066;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row0_col2 {
#             background-color:  #008066;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row1_col0 {
#             background-color:  #cfe766;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row1_col1 {
#             background-color:  #c2e066;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row1_col2 {
#             background-color:  #dbed66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row2_col0 {
#             background-color:  #dfef66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row2_col1 {
#             background-color:  #e1f066;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row2_col2 {
#             background-color:  #e3f166;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row3_col0 {
#             background-color:  #ffff66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row3_col1 {
#             background-color:  #fcfe66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row3_col2 {
#             background-color:  #fefe66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row4_col0 {
#             background-color:  #fefe66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row4_col1 {
#             background-color:  #ffff66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row4_col2 {
#             background-color:  #fefe66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row5_col0 {
#             background-color:  #ffff66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row5_col1 {
#             background-color:  #ffff66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row5_col2 {
#             background-color:  #fdfe66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row6_col0 {
#             background-color:  #ffff66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row6_col1 {
#             background-color:  #ffff66;
#         }    #T_a82e1bda_e527_11e8_a6fe_720002ee9960row6_col2 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_a82e1bda_e527_11e8_a6fe_720002ee9960" >
# <thead>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Parch</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a82e1bda_e527_11e8_a6fe_720002ee9960level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row0_col0" class="data row0 col0" >163</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row0_col1" class="data row0 col1" >134</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row0_col2" class="data row0 col2" >381</td>
#     </tr>    <tr>
#         <th id="T_a82e1bda_e527_11e8_a6fe_720002ee9960level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row1_col0" class="data row1 col0" >31</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row1_col1" class="data row1 col1" >32</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row1_col2" class="data row1 col2" >55</td>
#     </tr>    <tr>
#         <th id="T_a82e1bda_e527_11e8_a6fe_720002ee9960level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row2_col0" class="data row2 col0" >21</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row2_col1" class="data row2 col1" >16</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row2_col2" class="data row2 col2" >43</td>
#     </tr>    <tr>
#         <th id="T_a82e1bda_e527_11e8_a6fe_720002ee9960level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row3_col0" class="data row3 col0" >0</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row3_col1" class="data row3 col1" >2</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row3_col2" class="data row3 col2" >3</td>
#     </tr>    <tr>
#         <th id="T_a82e1bda_e527_11e8_a6fe_720002ee9960level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row4_col0" class="data row4 col0" >1</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row4_col1" class="data row4 col1" >0</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row4_col2" class="data row4 col2" >3</td>
#     </tr>    <tr>
#         <th id="T_a82e1bda_e527_11e8_a6fe_720002ee9960level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row5_col0" class="data row5 col0" >0</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row5_col1" class="data row5 col1" >0</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row5_col2" class="data row5 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_a82e1bda_e527_11e8_a6fe_720002ee9960level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row6_col0" class="data row6 col0" >0</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row6_col1" class="data row6 col1" >0</td>
#         <td id="T_a82e1bda_e527_11e8_a6fe_720002ee9960row6_col2" class="data row6 col2" >1</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# The crosstab again shows that larger families were in Pclass3.

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.close(2)
plt.show()

# %% [markdown]
# ### Observations:
#
# Here too the results are quite similar. Passengers with their parents onboard have greater chance of survival. It however reduces as the number goes up.
#
# The chances of survival is good for somebody who has 1-3 parents on the ship. Being alone also proves to be fatal and the chances for survival decreases when somebody has >4 parents on the ship.

# %% [markdown]
# ## Fare--> Continous Feature

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# There looks to be a large distribution in the fares of Passengers in Pclass1 and this distribution goes on decreasing as the standards reduces. As this is also continous, we can convert into discrete values by using binning.

# %% [markdown]
# ## Observations in a Nutshell for all features:
# **Sex:** The chance of survival for women is high as compared to men.
#
# **Pclass:**There is a visible trend that being a **1st class passenger** gives you better chances of survival. The survival rate for **Pclass3 is very low**. For **women**, the chance of survival from **Pclass1** is almost 1 and is high too for those from **Pclass2**.   **Money Wins!!!**.
#
# **Age:** Children less than 5-10 years do have a high chance of survival. Passengers between age group 15 to 35 died a lot.
#
# **Embarked:** This is a very interesting feature. **The chances of survival at C looks to be better than even though the majority of Pclass1 passengers got up at S.** Passengers at Q were all from **Pclass3**.
#
# **Parch+SibSp:** Having 1-2 siblings,spouse on board or 1-3 Parents shows a greater chance of probablity rather than being alone or having a large family travelling with you.

# %% [markdown]
# ## Correlation Between The Features

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# ### Interpreting The Heatmap
#
# The first thing to note is that only the numeric features are compared as it is obvious that we cannot correlate between alphabets or strings. Before understanding the plot, let us see what exactly correlation is.
#
# **POSITIVE CORRELATION:** If an **increase in feature A leads to increase in feature B, then they are positively correlated**. A value **1 means perfect positive correlation**.
#
# **NEGATIVE CORRELATION:** If an **increase in feature A leads to decrease in feature B, then they are negatively correlated**. A value **-1 means perfect negative correlation**.
#
# Now lets say that two features are highly or perfectly correlated, so the increase in one leads to increase in the other. This means that both the features are containing highly similar information and there is very little or no variance in information. This is known as **MultiColinearity** as both of them contains almost the same information.
#
# So do you think we should use both of them as **one of them is redundant**. While making or training models, we should try to eliminate redundant features as it reduces training time and many such advantages.
#
# Now from the above heatmap,we can see that the features are not much correlated. The highest correlation is between **SibSp and Parch i.e 0.41**. So we can carry on with all features.
